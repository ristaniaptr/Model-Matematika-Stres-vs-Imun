# %% [markdown]
# #KONDISI NORMAL

# %% [markdown]
# ## Kasus 1: Titik eq 1 stabil, titik eq 2 tidak eksis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar bidang fasa
x = np.linspace(0,900,20)
y = np.linspace(-10,150,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,alpha_f + theta*x*y - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 200, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([0,900])
plt.ylim([-10,80])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar bidang fasa
x = np.linspace(30,110,20)
y = np.linspace(-5,5,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,alpha_f + theta*x*y - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 100, 200)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([30,110])
plt.ylim([-5,5])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
# GRAFIK TERHADAP T
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

tspan = np.linspace(0, 100, 200)
z0 = [50,30]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=30")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=30')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,50]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=50")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=50')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,70]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=70")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=70')

# %% [markdown]
# ## Kasus 2: Titik eq 1 tidak stabil, titik eq 2 eksis dan stabil

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 10                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar bidang fasa
x = np.linspace(0,800,20)
y = np.linspace(-50,150,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,alpha_f + theta*x*y - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 200, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([20,800])
plt.ylim([-50,100])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 10                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar bidang fasa
x = np.linspace(10,110,20)
y = np.linspace(-2,6,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,alpha_f + theta*x*y - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 500, 500)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([10,110])
plt.ylim([-2,6])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
# GRAFIK TERHADAP T
alpha_f = 10                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit

#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = alpha_f + theta*x*y - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

tspan = np.linspace(0, 100, 200)
z0 = [50,30]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=30")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=30')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,50]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=50")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=50')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,70]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=70")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=70')

# %% [markdown]
# #KONDISI STRES

# %% [markdown]
# ## Kasus 1: Titik eq 1 stabil, titik eq 2 tidak eksis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 1/3

#menggambar bidang fasa
x = np.linspace(20,100,20)
y = np.linspace(-5,10,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 500, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([20,100])
plt.ylim([-5,10])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c =1/3
#menggambar bidang fasa
x = np.linspace(44,50,20)
y = np.linspace(-1,3,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 1000, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([44,50])
plt.ylim([-1,3])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
# GRAFIK TERHADAP T
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 1/3

#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

tspan = np.linspace(0, 100, 200)
z0 = [50,30]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=30")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=30')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,50]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=50")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=50')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,70]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=70")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=70')

# %% [markdown]
# ## Kasus 2: Titik eq 1 tidak stabil, titik eq 2  eksis dan stabil

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 2

#menggambar bidang fasa
x = np.linspace(0,100,20)
y = np.linspace(0,50,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 1000, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([0,100])
plt.ylim([0,50])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 2
#menggambar bidang fasa
x = np.linspace(30,50,20)
y = np.linspace(15,30,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 500, 1000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([30,50])
plt.ylim([15,30])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
# GRAFIK TERHADAP T
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 2
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

tspan = np.linspace(0, 100, 200)
z0 = [50,30]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=30")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=30')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,50]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=50")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=50')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,70]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=70")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=70')

# %% [markdown]
# ## Kasus 3: Titik eq pada c = 1/2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 1/2

#menggambar bidang fasa
x = np.linspace(0,500,20)
y = np.linspace(0,80,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 1000, 3000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([0,500])
plt.ylim([0,80])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#1 liter darah manusia mengandung 6* 10^9 fagosit
#anggap ukuran 1 sel manusia = 8 * 10 ^-9 liter, maka dalam sel tersebut ada sekitar 50 fagosit, jadi anggap f0 = 50
# fagosit umurnya 1-3 hari kan, anggap diambil usia maksimal (3 hari)

alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 1/2

#menggambar bidang fasa
x = np.linspace(35,50,20)
y = np.linspace(-2,5,20)
x,y = np.meshgrid(x,y)
plt.quiver(x,y,((alpha_f + theta*x*y)/(1+c)) - beta_f*x, delta_p*y - mu*y*x)
plt.xlabel('$x$')
plt.ylabel('$y$')
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

#anggap ada 3 jenis nilai awal patogen (lebih kecil, sama, lebih besar dari fagosit awal)
for i in [30,50,70]:
  tspan = np.linspace(0, 15000, 15000)
  z0 = [50,i]
  ys = odeint(model, z0, tspan)
  plt.plot(ys[:, 0],ys[:, 1]);

plt.xlim([35,50])
plt.ylim([-2,5])
plt.xlabel("fagosit")
plt.ylabel("patogen")
# Out:
# Text(0, 0.5, 'patogen')

# %%
# GRAFIK TERHADAP T
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kematian patogen akibat diserang fagosit
c = 1/2
#menggambar beberapa kurva solusi
def model(U,t):
  x,y = U
  dxdt = ((alpha_f + theta*x*y)/(1+c)) - beta_f*x
  dydt = delta_p*y - mu*y*x
  return [dxdt,dydt]

tspan = np.linspace(0, 100, 200)
z0 = [50,30]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=30")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=30')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,50]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=50")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=50')

# %%
tspan = np.linspace(0, 100, 200)
z0 = [50,70]
ys = odeint(model, z0, tspan)

plt.plot(tspan,ys[:, 0],label="f(t)");
plt.plot(tspan,ys[:, 1],label="p(t)");
plt.legend()
plt.xlabel("t")
plt.ylabel("Dinamika saat p(0)=70")
# Out:
# Text(0, 0.5, 'Dinamika saat p(0)=70')

# %% [markdown]
# #DIAGRAM BIFURKASI

# %%
#DIAGRAM BIFURKASI P-C
import matplotlib.pyplot as plt
import numpy as np

# parameter
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kemati


def p(c):
  return (beta_f*(1+c)*delta_p - alpha_f*mu)/(delta_p*theta)

c = np.linspace(1/2, 3, 200)
c1 = np.linspace(0,1/2, 200)
c2 = np.linspace(1/2, 3, 200)
dx = 0
p1 = [i*dx for i in range (200) ]

# plot diagram bifurkasi

plt.plot(c1,p1,label="Titik eq I stabil",color='blue')
plt.plot(c2,p1,color='blue',linestyle='dashed',label='Titik eq I tidak stabil')
plt.plot(c,p(c), label="Titik eq II stabil",color='orange')
plt.legend()
plt.xlabel("c")
plt.ylabel("p")
# Out:
# Text(0, 0.5, 'p')

# %%
#DIAGRAM BIFURKASI F-C
import matplotlib.pyplot as plt
import numpy as np

# parameter
alpha_f = 20                                    # konstanta produksi alami fagosit
theta = 0.02                                     # rasio produksi fagosit akibat adanya patogen
beta_f = 1/3                                    # rasio kematian alami fagosit
alpha_p = 1/2                                   # rasio produksi alami patogen
beta_p = 0.46                                   # rasio kematian alami patogen
delta_p = alpha_p - beta_p                      # selisih antara rasio kelahiran dan kematian alami patogen
mu = 0.001                                        # rasio kemati

def f1(c1):
  return alpha_f/(beta_f*(1+c1))

c = np.linspace(1/2, 3, 200)
c1 = np.linspace(0,1/2, 200)
c2 = np.linspace(1/2, 3, 200)
dx = delta_p/mu
f2 = [dx for i in range (200)]

# plot diagram bifurkasi
plt.plot(c1,f1(c1),label="Titik eq I stabil",color="blue")
plt.plot(c2,f1(c2),label="Titik eq I tak stabil",color="blue", linestyle="dashed")
plt.plot(c,f2,label="Titik eq II stabil",color="orange")
plt.legend()
plt.xlabel("c")
plt.ylabel("f")
# Out:
# Text(0, 0.5, 'f')
